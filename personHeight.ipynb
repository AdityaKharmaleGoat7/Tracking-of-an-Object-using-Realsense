# %%
import pyrealsense2 as rs
import numpy as np
import cv2
import tensorflow as tf

W = 848
H = 480

# Configure depth and color streams
pipeline = rs.pipeline()
config = rs.config()
config.enable_stream(rs.stream.depth, W, H, rs.format.z16, 30)
config.enable_stream(rs.stream.color, W, H, rs.format.bgr8, 30)


print("[INFO] start streaming...")
pipeline.start(config)

aligned_stream = rs.align(rs.stream.color) # alignment between color and depth
point_cloud = rs.pointcloud()

print("[INFO] loading model...")
PATH_TO_CKPT = r"frozen_inference_graph.pb"
# download model from: https://github.com/opencv/opencv/wiki/TensorFlow-Object-Detection-API#run-network-in-opencv

# Load the Tensorflow model into memory.
detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.compat.v1.GraphDef()
    with tf.compat.v1.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.compat.v1.import_graph_def(od_graph_def, name='')
    sess = tf.compat.v1.Session(graph=detection_graph)

# Input tensor is the image
image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')
# Output tensors are the detection boxes, scores, and classes
# Each box represents a part of the image where a particular object was detected
detection_boxes = detection_graph.get_tensor_by_name('detection_boxes:0')
# Each score represents level of confidence for each of the objects.
# The score is shown on the result image, together with the class label.
detection_scores = detection_graph.get_tensor_by_name('detection_scores:0')
detection_classes = detection_graph.get_tensor_by_name('detection_classes:0')
# Number of objects detected
num_detections = detection_graph.get_tensor_by_name('num_detections:0')
# code source of tensorflow model loading: https://www.geeksforgeeks.org/ml-training-image-classifier-using-tensorflow-object-detection-api/

while True:
    frames = pipeline.wait_for_frames()
    frames = aligned_stream.process(frames)
    depth_frame = frames.get_depth_frame()
    color_frame = frames.get_color_frame()
    points = point_cloud.calculate(depth_frame)
    verts = np.asanyarray(points.get_vertices()).view(np.float32).reshape(-1, W, 3)  # xyz

    # Convert images to numpy arrays
    color_image = np.asanyarray(color_frame.get_data())
    scaled_size = (int(W), int(H))
    # expand image dimensions to have shape: [1, None, None, 3]
    # i.e. a single-column array, where each item in the column has the pixel RGB value
    image_expanded = np.expand_dims(color_image, axis=0)
    # Perform the actual detection by running the model with the image as input
    (boxes, scores, classes, num) = sess.run([detection_boxes, detection_scores, detection_classes, num_detections],
                                             feed_dict={image_tensor: image_expanded})

    boxes = np.squeeze(boxes)
    classes = np.squeeze(classes).astype(np.int32)
    scores = np.squeeze(scores)

    print("[INFO] drawing bounding box on detected objects...")
    print("[INFO] each detected object has a unique color")

    for idx in range(int(num)):
        class_ = classes[idx]
        score = scores[idx]
        box = boxes[idx]
        print(" [DEBUG] class : ", class_, "idx : ", idx, "num : ", num)

        if score > 0.8 and class_ == 1: # 1 for human
            left = box[1] * W
            top = box[0] * H
            right = box[3] * W
            bottom = box[2] * H

            width = right - left
            height = bottom - top
            bbox = (int(left), int(top), int(width), int(height))
            p1 = (int(bbox[0]), int(bbox[1]))
            p2 = (int(bbox[0] + bbox[2]), int(bbox[1] + bbox[3]))
            # draw box
            cv2.rectangle(color_image, p1, p2, (255,0,0), 2, 1)

            # x,y,z of bounding box
            obj_points = verts[int(bbox[1]):int(bbox[1] + bbox[3]), int(bbox[0]):int(bbox[0] + bbox[2])].reshape(-1, 3)
            zs = obj_points[:, 2]

            z = np.median(zs)

            ys = obj_points[:, 1]
            ys = np.delete(ys, np.where(
                (zs < z - 1) | (zs > z + 1)))  # take only y for close z to prevent including background

            my = np.amin(ys, initial=1)
            My = np.amax(ys, initial=-1)

            height = (My - my)  # add next to rectangle print of height using cv library
            height = float("{:.2f}".format(height))
            print("[INFO] object height is: ", height, "[m]")
            height_txt = str(height) + "[m]"

            # Write some Text
            font = cv2.FONT_HERSHEY_SIMPLEX
            bottomLeftCornerOfText = (p1[0], p1[1] + 20)
            fontScale = 1
            fontColor = (255, 255, 255)
            lineType = 2
            cv2.putText(color_image, height_txt,
                        bottomLeftCornerOfText,
                        font,
                        fontScale,
                        fontColor,
                        lineType)

    # Show images
    cv2.namedWindow('RealSense', cv2.WINDOW_AUTOSIZE)
    cv2.imshow('RealSense', color_image)
    cv2.waitKey(1)

# Stop streaming
pipeline.stop()
# Out:
# 2024-06-13 11:57:13.027641: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-13 11:57:13.752833: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [INFO] start streaming...
# [INFO] loading model...
# 2024-06-13 11:57:16.162932: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1718247438.048247   16141 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -7 } dim { size: -10 } dim { size: -12 } dim { size: 576 } } } inputs { dtype: DT_FLOAT shape { dim { size: -33 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -33 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2299 num_cores: 12 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 12582912 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -33 } dim { size: 14 } dim { size: 14 } dim { size: 576 } } }
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [8.]
#  [DEBUG] class :  1 idx :  1 num :  [8.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  2 num :  [8.]
# [INFO] object height is:  0.34 [m]
#  [DEBUG] class :  1 idx :  3 num :  [8.]
# [INFO] object height is:  0.02 [m]
#  [DEBUG] class :  73 idx :  4 num :  [8.]
#  [DEBUG] class :  1 idx :  5 num :  [8.]
#  [DEBUG] class :  62 idx :  6 num :  [8.]
#  [DEBUG] class :  62 idx :  7 num :  [8.]
# /tmp/ipykernel_16141/127782046.py:74: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   for idx in range(int(num)):
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [8.]
#  [DEBUG] class :  1 idx :  1 num :  [8.]
# [INFO] object height is:  0.33 [m]
#  [DEBUG] class :  1 idx :  2 num :  [8.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  3 num :  [8.]
#  [DEBUG] class :  1 idx :  4 num :  [8.]
#  [DEBUG] class :  73 idx :  5 num :  [8.]
#  [DEBUG] class :  1 idx :  6 num :  [8.]
#  [DEBUG] class :  62 idx :  7 num :  [8.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.32 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
#  [DEBUG] class :  1 idx :  4 num :  [9.]
#  [DEBUG] class :  73 idx :  5 num :  [9.]
#  [DEBUG] class :  62 idx :  6 num :  [9.]
#  [DEBUG] class :  1 idx :  7 num :  [9.]
#  [DEBUG] class :  63 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [8.]
#  [DEBUG] class :  1 idx :  1 num :  [8.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  2 num :  [8.]
# [INFO] object height is:  0.31 [m]
#  [DEBUG] class :  1 idx :  3 num :  [8.]
#  [DEBUG] class :  73 idx :  4 num :  [8.]
#  [DEBUG] class :  1 idx :  5 num :  [8.]
#  [DEBUG] class :  63 idx :  6 num :  [8.]
#  [DEBUG] class :  62 idx :  7 num :  [8.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [6.]
#  [DEBUG] class :  1 idx :  1 num :  [6.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  2 num :  [6.]
# [INFO] object height is:  0.31 [m]
#  [DEBUG] class :  1 idx :  3 num :  [6.]
#  [DEBUG] class :  1 idx :  4 num :  [6.]
#  [DEBUG] class :  63 idx :  5 num :  [6.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [7.]
#  [DEBUG] class :  1 idx :  1 num :  [7.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  2 num :  [7.]
# [INFO] object height is:  0.35 [m]
#  [DEBUG] class :  1 idx :  3 num :  [7.]
#  [DEBUG] class :  1 idx :  4 num :  [7.]
#  [DEBUG] class :  73 idx :  5 num :  [7.]
#  [DEBUG] class :  62 idx :  6 num :  [7.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [7.]
#  [DEBUG] class :  1 idx :  1 num :  [7.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  2 num :  [7.]
# [INFO] object height is:  0.32 [m]
#  [DEBUG] class :  1 idx :  3 num :  [7.]
#  [DEBUG] class :  1 idx :  4 num :  [7.]
#  [DEBUG] class :  73 idx :  5 num :  [7.]
#  [DEBUG] class :  62 idx :  6 num :  [7.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [7.]
#  [DEBUG] class :  1 idx :  1 num :  [7.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  2 num :  [7.]
# [INFO] object height is:  0.31 [m]
#  [DEBUG] class :  1 idx :  3 num :  [7.]
#  [DEBUG] class :  1 idx :  4 num :  [7.]
#  [DEBUG] class :  73 idx :  5 num :  [7.]
#  [DEBUG] class :  1 idx :  6 num :  [7.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.35 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
#  [DEBUG] class :  1 idx :  4 num :  [9.]
#  [DEBUG] class :  73 idx :  5 num :  [9.]
#  [DEBUG] class :  1 idx :  6 num :  [9.]
#  [DEBUG] class :  62 idx :  7 num :  [9.]
#  [DEBUG] class :  67 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [8.]
#  [DEBUG] class :  1 idx :  1 num :  [8.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  2 num :  [8.]
# [INFO] object height is:  0.31 [m]
#  [DEBUG] class :  1 idx :  3 num :  [8.]
# [INFO] object height is:  0.02 [m]
#  [DEBUG] class :  1 idx :  4 num :  [8.]
#  [DEBUG] class :  73 idx :  5 num :  [8.]
#  [DEBUG] class :  1 idx :  6 num :  [8.]
#  [DEBUG] class :  84 idx :  7 num :  [8.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.32 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  73 idx :  4 num :  [9.]
#  [DEBUG] class :  1 idx :  5 num :  [9.]
#  [DEBUG] class :  62 idx :  6 num :  [9.]
#  [DEBUG] class :  63 idx :  7 num :  [9.]
#  [DEBUG] class :  84 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [8.]
#  [DEBUG] class :  1 idx :  1 num :  [8.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  2 num :  [8.]
# [INFO] object height is:  0.36 [m]
#  [DEBUG] class :  1 idx :  3 num :  [8.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  73 idx :  4 num :  [8.]
#  [DEBUG] class :  1 idx :  5 num :  [8.]
#  [DEBUG] class :  1 idx :  6 num :  [8.]
#  [DEBUG] class :  62 idx :  7 num :  [8.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [8.]
#  [DEBUG] class :  1 idx :  1 num :  [8.]
# [INFO] object height is:  0.36 [m]
#  [DEBUG] class :  1 idx :  2 num :  [8.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  3 num :  [8.]
# [INFO] object height is:  0.02 [m]
#  [DEBUG] class :  1 idx :  4 num :  [8.]
# [INFO] object height is:  0.34 [m]
#  [DEBUG] class :  73 idx :  5 num :  [8.]
#  [DEBUG] class :  1 idx :  6 num :  [8.]
#  [DEBUG] class :  63 idx :  7 num :  [8.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.32 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  4 num :  [9.]
#  [DEBUG] class :  73 idx :  5 num :  [9.]
#  [DEBUG] class :  62 idx :  6 num :  [9.]
#  [DEBUG] class :  84 idx :  7 num :  [9.]
#  [DEBUG] class :  63 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.31 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
#  [DEBUG] class :  1 idx :  4 num :  [9.]
#  [DEBUG] class :  1 idx :  5 num :  [9.]
#  [DEBUG] class :  73 idx :  6 num :  [9.]
#  [DEBUG] class :  1 idx :  7 num :  [9.]
#  [DEBUG] class :  62 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [8.]
#  [DEBUG] class :  1 idx :  1 num :  [8.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  2 num :  [8.]
# [INFO] object height is:  0.32 [m]
#  [DEBUG] class :  1 idx :  3 num :  [8.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  4 num :  [8.]
#  [DEBUG] class :  73 idx :  5 num :  [8.]
#  [DEBUG] class :  62 idx :  6 num :  [8.]
#  [DEBUG] class :  63 idx :  7 num :  [8.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [7.]
#  [DEBUG] class :  1 idx :  1 num :  [7.]
# [INFO] object height is:  0.36 [m]
#  [DEBUG] class :  1 idx :  2 num :  [7.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  3 num :  [7.]
# [INFO] object height is:  0.0 [m]
#  [DEBUG] class :  1 idx :  4 num :  [7.]
#  [DEBUG] class :  73 idx :  5 num :  [7.]
#  [DEBUG] class :  1 idx :  6 num :  [7.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [13.]
#  [DEBUG] class :  1 idx :  1 num :  [13.]
# [INFO] object height is:  0.37 [m]
#  [DEBUG] class :  1 idx :  2 num :  [13.]
# [INFO] object height is:  0.39 [m]
#  [DEBUG] class :  1 idx :  3 num :  [13.]
# [INFO] object height is:  0.49 [m]
#  [DEBUG] class :  1 idx :  4 num :  [13.]
# [INFO] object height is:  0.36 [m]
#  [DEBUG] class :  1 idx :  5 num :  [13.]
#  [DEBUG] class :  1 idx :  6 num :  [13.]
#  [DEBUG] class :  1 idx :  7 num :  [13.]
#  [DEBUG] class :  1 idx :  8 num :  [13.]
#  [DEBUG] class :  1 idx :  9 num :  [13.]
#  [DEBUG] class :  1 idx :  10 num :  [13.]
#  [DEBUG] class :  76 idx :  11 num :  [13.]
#  [DEBUG] class :  73 idx :  12 num :  [13.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [12.]
#  [DEBUG] class :  1 idx :  1 num :  [12.]
# [INFO] object height is:  0.57 [m]
#  [DEBUG] class :  1 idx :  2 num :  [12.]
# [INFO] object height is:  0.44 [m]
#  [DEBUG] class :  1 idx :  3 num :  [12.]
# [INFO] object height is:  0.52 [m]
#  [DEBUG] class :  1 idx :  4 num :  [12.]
# [INFO] object height is:  0.44 [m]
#  [DEBUG] class :  1 idx :  5 num :  [12.]
#  [DEBUG] class :  73 idx :  6 num :  [12.]
#  [DEBUG] class :  1 idx :  7 num :  [12.]
#  [DEBUG] class :  76 idx :  8 num :  [12.]
#  [DEBUG] class :  73 idx :  9 num :  [12.]
#  [DEBUG] class :  67 idx :  10 num :  [12.]
#  [DEBUG] class :  1 idx :  11 num :  [12.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [10.]
#  [DEBUG] class :  1 idx :  1 num :  [10.]
# [INFO] object height is:  0.53 [m]
#  [DEBUG] class :  1 idx :  2 num :  [10.]
# [INFO] object height is:  0.45 [m]
#  [DEBUG] class :  1 idx :  3 num :  [10.]
#  [DEBUG] class :  1 idx :  4 num :  [10.]
#  [DEBUG] class :  1 idx :  5 num :  [10.]
#  [DEBUG] class :  1 idx :  6 num :  [10.]
#  [DEBUG] class :  1 idx :  7 num :  [10.]
#  [DEBUG] class :  76 idx :  8 num :  [10.]
#  [DEBUG] class :  18 idx :  9 num :  [10.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [11.]
#  [DEBUG] class :  1 idx :  1 num :  [11.]
# [INFO] object height is:  0.61 [m]
#  [DEBUG] class :  1 idx :  2 num :  [11.]
# [INFO] object height is:  0.48 [m]
#  [DEBUG] class :  1 idx :  3 num :  [11.]
# [INFO] object height is:  1.27 [m]
#  [DEBUG] class :  1 idx :  4 num :  [11.]
# [INFO] object height is:  0.34 [m]
#  [DEBUG] class :  1 idx :  5 num :  [11.]
#  [DEBUG] class :  1 idx :  6 num :  [11.]
#  [DEBUG] class :  62 idx :  7 num :  [11.]
#  [DEBUG] class :  1 idx :  8 num :  [11.]
#  [DEBUG] class :  62 idx :  9 num :  [11.]
#  [DEBUG] class :  1 idx :  10 num :  [11.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [10.]
#  [DEBUG] class :  1 idx :  1 num :  [10.]
# [INFO] object height is:  0.49 [m]
#  [DEBUG] class :  1 idx :  2 num :  [10.]
# [INFO] object height is:  0.59 [m]
#  [DEBUG] class :  1 idx :  3 num :  [10.]
# [INFO] object height is:  0.49 [m]
#  [DEBUG] class :  1 idx :  4 num :  [10.]
#  [DEBUG] class :  1 idx :  5 num :  [10.]
#  [DEBUG] class :  62 idx :  6 num :  [10.]
#  [DEBUG] class :  1 idx :  7 num :  [10.]
#  [DEBUG] class :  1 idx :  8 num :  [10.]
#  [DEBUG] class :  62 idx :  9 num :  [10.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [10.]
#  [DEBUG] class :  1 idx :  1 num :  [10.]
# [INFO] object height is:  0.66 [m]
#  [DEBUG] class :  1 idx :  2 num :  [10.]
# [INFO] object height is:  0.59 [m]
#  [DEBUG] class :  1 idx :  3 num :  [10.]
# [INFO] object height is:  1.44 [m]
#  [DEBUG] class :  1 idx :  4 num :  [10.]
# [INFO] object height is:  0.44 [m]
#  [DEBUG] class :  1 idx :  5 num :  [10.]
#  [DEBUG] class :  1 idx :  6 num :  [10.]
#  [DEBUG] class :  62 idx :  7 num :  [10.]
#  [DEBUG] class :  62 idx :  8 num :  [10.]
#  [DEBUG] class :  62 idx :  9 num :  [10.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [8.]
#  [DEBUG] class :  1 idx :  1 num :  [8.]
# [INFO] object height is:  0.64 [m]
#  [DEBUG] class :  1 idx :  2 num :  [8.]
# [INFO] object height is:  0.55 [m]
#  [DEBUG] class :  1 idx :  3 num :  [8.]
#  [DEBUG] class :  1 idx :  4 num :  [8.]
#  [DEBUG] class :  1 idx :  5 num :  [8.]
#  [DEBUG] class :  62 idx :  6 num :  [8.]
#  [DEBUG] class :  1 idx :  7 num :  [8.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.65 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.53 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
#  [DEBUG] class :  1 idx :  4 num :  [9.]
#  [DEBUG] class :  1 idx :  5 num :  [9.]
#  [DEBUG] class :  62 idx :  6 num :  [9.]
#  [DEBUG] class :  1 idx :  7 num :  [9.]
#  [DEBUG] class :  62 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [8.]
#  [DEBUG] class :  1 idx :  1 num :  [8.]
# [INFO] object height is:  0.57 [m]
#  [DEBUG] class :  1 idx :  2 num :  [8.]
# [INFO] object height is:  1.33 [m]
#  [DEBUG] class :  1 idx :  3 num :  [8.]
# [INFO] object height is:  0.55 [m]
#  [DEBUG] class :  1 idx :  4 num :  [8.]
#  [DEBUG] class :  1 idx :  5 num :  [8.]
#  [DEBUG] class :  62 idx :  6 num :  [8.]
#  [DEBUG] class :  1 idx :  7 num :  [8.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [11.]
#  [DEBUG] class :  1 idx :  1 num :  [11.]
# [INFO] object height is:  0.55 [m]
#  [DEBUG] class :  1 idx :  2 num :  [11.]
# [INFO] object height is:  0.63 [m]
#  [DEBUG] class :  1 idx :  3 num :  [11.]
# [INFO] object height is:  0.78 [m]
#  [DEBUG] class :  72 idx :  4 num :  [11.]
#  [DEBUG] class :  1 idx :  5 num :  [11.]
#  [DEBUG] class :  1 idx :  6 num :  [11.]
#  [DEBUG] class :  1 idx :  7 num :  [11.]
#  [DEBUG] class :  1 idx :  8 num :  [11.]
#  [DEBUG] class :  62 idx :  9 num :  [11.]
#  [DEBUG] class :  62 idx :  10 num :  [11.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [11.]
#  [DEBUG] class :  1 idx :  1 num :  [11.]
# [INFO] object height is:  0.57 [m]
#  [DEBUG] class :  1 idx :  2 num :  [11.]
# [INFO] object height is:  0.51 [m]
#  [DEBUG] class :  1 idx :  3 num :  [11.]
# [INFO] object height is:  0.77 [m]
#  [DEBUG] class :  1 idx :  4 num :  [11.]
#  [DEBUG] class :  1 idx :  5 num :  [11.]
#  [DEBUG] class :  1 idx :  6 num :  [11.]
#  [DEBUG] class :  62 idx :  7 num :  [11.]
#  [DEBUG] class :  1 idx :  8 num :  [11.]
#  [DEBUG] class :  62 idx :  9 num :  [11.]
#  [DEBUG] class :  62 idx :  10 num :  [11.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [11.]
#  [DEBUG] class :  1 idx :  1 num :  [11.]
# [INFO] object height is:  0.5 [m]
#  [DEBUG] class :  1 idx :  2 num :  [11.]
# [INFO] object height is:  0.59 [m]
#  [DEBUG] class :  1 idx :  3 num :  [11.]
# [INFO] object height is:  0.78 [m]
#  [DEBUG] class :  1 idx :  4 num :  [11.]
#  [DEBUG] class :  1 idx :  5 num :  [11.]
#  [DEBUG] class :  1 idx :  6 num :  [11.]
#  [DEBUG] class :  72 idx :  7 num :  [11.]
#  [DEBUG] class :  1 idx :  8 num :  [11.]
#  [DEBUG] class :  62 idx :  9 num :  [11.]
#  [DEBUG] class :  62 idx :  10 num :  [11.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [12.]
#  [DEBUG] class :  1 idx :  1 num :  [12.]
# [INFO] object height is:  0.59 [m]
#  [DEBUG] class :  1 idx :  2 num :  [12.]
# [INFO] object height is:  0.23 [m]
#  [DEBUG] class :  1 idx :  3 num :  [12.]
# [INFO] object height is:  0.52 [m]
#  [DEBUG] class :  1 idx :  4 num :  [12.]
#  [DEBUG] class :  1 idx :  5 num :  [12.]
#  [DEBUG] class :  72 idx :  6 num :  [12.]
#  [DEBUG] class :  62 idx :  7 num :  [12.]
#  [DEBUG] class :  1 idx :  8 num :  [12.]
#  [DEBUG] class :  62 idx :  9 num :  [12.]
#  [DEBUG] class :  1 idx :  10 num :  [12.]
#  [DEBUG] class :  1 idx :  11 num :  [12.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [11.]
#  [DEBUG] class :  1 idx :  1 num :  [11.]
# [INFO] object height is:  0.58 [m]
#  [DEBUG] class :  1 idx :  2 num :  [11.]
# [INFO] object height is:  0.55 [m]
#  [DEBUG] class :  1 idx :  3 num :  [11.]
# [INFO] object height is:  0.76 [m]
#  [DEBUG] class :  1 idx :  4 num :  [11.]
# [INFO] object height is:  0.23 [m]
#  [DEBUG] class :  1 idx :  5 num :  [11.]
#  [DEBUG] class :  62 idx :  6 num :  [11.]
#  [DEBUG] class :  1 idx :  7 num :  [11.]
#  [DEBUG] class :  1 idx :  8 num :  [11.]
#  [DEBUG] class :  62 idx :  9 num :  [11.]
#  [DEBUG] class :  1 idx :  10 num :  [11.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [10.]
#  [DEBUG] class :  1 idx :  1 num :  [10.]
# [INFO] object height is:  0.57 [m]
#  [DEBUG] class :  1 idx :  2 num :  [10.]
# [INFO] object height is:  0.54 [m]
#  [DEBUG] class :  1 idx :  3 num :  [10.]
#  [DEBUG] class :  1 idx :  4 num :  [10.]
#  [DEBUG] class :  1 idx :  5 num :  [10.]
#  [DEBUG] class :  62 idx :  6 num :  [10.]
#  [DEBUG] class :  1 idx :  7 num :  [10.]
#  [DEBUG] class :  1 idx :  8 num :  [10.]
#  [DEBUG] class :  62 idx :  9 num :  [10.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [11.]
#  [DEBUG] class :  1 idx :  1 num :  [11.]
# [INFO] object height is:  0.58 [m]
#  [DEBUG] class :  1 idx :  2 num :  [11.]
# [INFO] object height is:  0.5 [m]
#  [DEBUG] class :  1 idx :  3 num :  [11.]
# [INFO] object height is:  0.78 [m]
#  [DEBUG] class :  1 idx :  4 num :  [11.]
#  [DEBUG] class :  1 idx :  5 num :  [11.]
#  [DEBUG] class :  62 idx :  6 num :  [11.]
#  [DEBUG] class :  1 idx :  7 num :  [11.]
#  [DEBUG] class :  1 idx :  8 num :  [11.]
#  [DEBUG] class :  1 idx :  9 num :  [11.]
#  [DEBUG] class :  62 idx :  10 num :  [11.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.57 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.49 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
# [INFO] object height is:  0.78 [m]
#  [DEBUG] class :  1 idx :  4 num :  [9.]
#  [DEBUG] class :  1 idx :  5 num :  [9.]
#  [DEBUG] class :  1 idx :  6 num :  [9.]
#  [DEBUG] class :  62 idx :  7 num :  [9.]
#  [DEBUG] class :  62 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.49 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.66 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
#  [DEBUG] class :  1 idx :  4 num :  [9.]
#  [DEBUG] class :  1 idx :  5 num :  [9.]
#  [DEBUG] class :  62 idx :  6 num :  [9.]
#  [DEBUG] class :  62 idx :  7 num :  [9.]
#  [DEBUG] class :  1 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [10.]
#  [DEBUG] class :  1 idx :  1 num :  [10.]
# [INFO] object height is:  0.59 [m]
#  [DEBUG] class :  1 idx :  2 num :  [10.]
# [INFO] object height is:  0.57 [m]
#  [DEBUG] class :  1 idx :  3 num :  [10.]
# [INFO] object height is:  0.94 [m]
#  [DEBUG] class :  1 idx :  4 num :  [10.]
#  [DEBUG] class :  1 idx :  5 num :  [10.]
#  [DEBUG] class :  1 idx :  6 num :  [10.]
#  [DEBUG] class :  62 idx :  7 num :  [10.]
#  [DEBUG] class :  1 idx :  8 num :  [10.]
#  [DEBUG] class :  1 idx :  9 num :  [10.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [10.]
#  [DEBUG] class :  1 idx :  1 num :  [10.]
# [INFO] object height is:  0.67 [m]
#  [DEBUG] class :  1 idx :  2 num :  [10.]
# [INFO] object height is:  0.58 [m]
#  [DEBUG] class :  1 idx :  3 num :  [10.]
# [INFO] object height is:  0.86 [m]
#  [DEBUG] class :  1 idx :  4 num :  [10.]
#  [DEBUG] class :  1 idx :  5 num :  [10.]
#  [DEBUG] class :  72 idx :  6 num :  [10.]
#  [DEBUG] class :  1 idx :  7 num :  [10.]
#  [DEBUG] class :  62 idx :  8 num :  [10.]
#  [DEBUG] class :  1 idx :  9 num :  [10.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [10.]
#  [DEBUG] class :  1 idx :  1 num :  [10.]
# [INFO] object height is:  0.56 [m]
#  [DEBUG] class :  1 idx :  2 num :  [10.]
# [INFO] object height is:  0.25 [m]
#  [DEBUG] class :  1 idx :  3 num :  [10.]
# [INFO] object height is:  0.5 [m]
#  [DEBUG] class :  1 idx :  4 num :  [10.]
#  [DEBUG] class :  1 idx :  5 num :  [10.]
#  [DEBUG] class :  76 idx :  6 num :  [10.]
#  [DEBUG] class :  1 idx :  7 num :  [10.]
#  [DEBUG] class :  73 idx :  8 num :  [10.]
#  [DEBUG] class :  31 idx :  9 num :  [10.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [6.]
#  [DEBUG] class :  1 idx :  1 num :  [6.]
# [INFO] object height is:  0.37 [m]
#  [DEBUG] class :  1 idx :  2 num :  [6.]
# [INFO] object height is:  0.64 [m]
#  [DEBUG] class :  1 idx :  3 num :  [6.]
# [INFO] object height is:  0.57 [m]
#  [DEBUG] class :  62 idx :  4 num :  [6.]
#  [DEBUG] class :  1 idx :  5 num :  [6.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [7.]
#  [DEBUG] class :  1 idx :  1 num :  [7.]
# [INFO] object height is:  0.37 [m]
#  [DEBUG] class :  1 idx :  2 num :  [7.]
# [INFO] object height is:  0.67 [m]
#  [DEBUG] class :  1 idx :  3 num :  [7.]
# [INFO] object height is:  0.61 [m]
#  [DEBUG] class :  1 idx :  4 num :  [7.]
#  [DEBUG] class :  62 idx :  5 num :  [7.]
#  [DEBUG] class :  62 idx :  6 num :  [7.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [8.]
#  [DEBUG] class :  1 idx :  1 num :  [8.]
# [INFO] object height is:  0.69 [m]
#  [DEBUG] class :  1 idx :  2 num :  [8.]
# [INFO] object height is:  0.31 [m]
#  [DEBUG] class :  1 idx :  3 num :  [8.]
# [INFO] object height is:  0.58 [m]
#  [DEBUG] class :  1 idx :  4 num :  [8.]
#  [DEBUG] class :  62 idx :  5 num :  [8.]
#  [DEBUG] class :  62 idx :  6 num :  [8.]
#  [DEBUG] class :  1 idx :  7 num :  [8.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [12.]
#  [DEBUG] class :  1 idx :  1 num :  [12.]
# [INFO] object height is:  0.33 [m]
#  [DEBUG] class :  1 idx :  2 num :  [12.]
# [INFO] object height is:  0.67 [m]
#  [DEBUG] class :  1 idx :  3 num :  [12.]
# [INFO] object height is:  0.52 [m]
#  [DEBUG] class :  1 idx :  4 num :  [12.]
#  [DEBUG] class :  62 idx :  5 num :  [12.]
#  [DEBUG] class :  76 idx :  6 num :  [12.]
#  [DEBUG] class :  62 idx :  7 num :  [12.]
#  [DEBUG] class :  62 idx :  8 num :  [12.]
#  [DEBUG] class :  62 idx :  9 num :  [12.]
#  [DEBUG] class :  1 idx :  10 num :  [12.]
#  [DEBUG] class :  32 idx :  11 num :  [12.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [15.]
#  [DEBUG] class :  1 idx :  1 num :  [15.]
# [INFO] object height is:  0.74 [m]
#  [DEBUG] class :  1 idx :  2 num :  [15.]
# [INFO] object height is:  0.51 [m]
#  [DEBUG] class :  1 idx :  3 num :  [15.]
# [INFO] object height is:  0.33 [m]
#  [DEBUG] class :  1 idx :  4 num :  [15.]
#  [DEBUG] class :  1 idx :  5 num :  [15.]
#  [DEBUG] class :  74 idx :  6 num :  [15.]
#  [DEBUG] class :  1 idx :  7 num :  [15.]
#  [DEBUG] class :  62 idx :  8 num :  [15.]
#  [DEBUG] class :  62 idx :  9 num :  [15.]
#  [DEBUG] class :  1 idx :  10 num :  [15.]
#  [DEBUG] class :  76 idx :  11 num :  [15.]
#  [DEBUG] class :  62 idx :  12 num :  [15.]
#  [DEBUG] class :  62 idx :  13 num :  [15.]
#  [DEBUG] class :  76 idx :  14 num :  [15.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [13.]
#  [DEBUG] class :  1 idx :  1 num :  [13.]
# [INFO] object height is:  0.3 [m]
#  [DEBUG] class :  1 idx :  2 num :  [13.]
# [INFO] object height is:  0.64 [m]
#  [DEBUG] class :  1 idx :  3 num :  [13.]
# [INFO] object height is:  0.55 [m]
#  [DEBUG] class :  1 idx :  4 num :  [13.]
# [INFO] object height is:  0.44 [m]
#  [DEBUG] class :  76 idx :  5 num :  [13.]
#  [DEBUG] class :  62 idx :  6 num :  [13.]
#  [DEBUG] class :  62 idx :  7 num :  [13.]
#  [DEBUG] class :  62 idx :  8 num :  [13.]
#  [DEBUG] class :  1 idx :  9 num :  [13.]
#  [DEBUG] class :  1 idx :  10 num :  [13.]
#  [DEBUG] class :  62 idx :  11 num :  [13.]
#  [DEBUG] class :  1 idx :  12 num :  [13.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [14.]
#  [DEBUG] class :  1 idx :  1 num :  [14.]
# [INFO] object height is:  0.66 [m]
#  [DEBUG] class :  1 idx :  2 num :  [14.]
# [INFO] object height is:  0.36 [m]
#  [DEBUG] class :  1 idx :  3 num :  [14.]
# [INFO] object height is:  0.6 [m]
#  [DEBUG] class :  1 idx :  4 num :  [14.]
# [INFO] object height is:  0.46 [m]
#  [DEBUG] class :  1 idx :  5 num :  [14.]
#  [DEBUG] class :  73 idx :  6 num :  [14.]
#  [DEBUG] class :  76 idx :  7 num :  [14.]
#  [DEBUG] class :  62 idx :  8 num :  [14.]
#  [DEBUG] class :  1 idx :  9 num :  [14.]
#  [DEBUG] class :  1 idx :  10 num :  [14.]
#  [DEBUG] class :  42 idx :  11 num :  [14.]
#  [DEBUG] class :  1 idx :  12 num :  [14.]
#  [DEBUG] class :  62 idx :  13 num :  [14.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.34 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.53 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
# [INFO] object height is:  0.58 [m]
#  [DEBUG] class :  76 idx :  4 num :  [9.]
#  [DEBUG] class :  1 idx :  5 num :  [9.]
#  [DEBUG] class :  62 idx :  6 num :  [9.]
#  [DEBUG] class :  74 idx :  7 num :  [9.]
#  [DEBUG] class :  1 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.33 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.75 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
#  [DEBUG] class :  1 idx :  4 num :  [9.]
#  [DEBUG] class :  76 idx :  5 num :  [9.]
#  [DEBUG] class :  1 idx :  6 num :  [9.]
#  [DEBUG] class :  62 idx :  7 num :  [9.]
#  [DEBUG] class :  31 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  1 idx :  0 num :  [8.]
# [INFO] object height is:  0.58 [m]
#  [DEBUG] class :  1 idx :  1 num :  [8.]
# [INFO] object height is:  0.66 [m]
#  [DEBUG] class :  73 idx :  2 num :  [8.]
#  [DEBUG] class :  1 idx :  3 num :  [8.]
#  [DEBUG] class :  1 idx :  4 num :  [8.]
#  [DEBUG] class :  62 idx :  5 num :  [8.]
#  [DEBUG] class :  1 idx :  6 num :  [8.]
#  [DEBUG] class :  1 idx :  7 num :  [8.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [10.]
#  [DEBUG] class :  1 idx :  1 num :  [10.]
# [INFO] object height is:  0.35 [m]
#  [DEBUG] class :  1 idx :  2 num :  [10.]
# [INFO] object height is:  0.59 [m]
#  [DEBUG] class :  1 idx :  3 num :  [10.]
# [INFO] object height is:  0.53 [m]
#  [DEBUG] class :  1 idx :  4 num :  [10.]
#  [DEBUG] class :  76 idx :  5 num :  [10.]
#  [DEBUG] class :  62 idx :  6 num :  [10.]
#  [DEBUG] class :  1 idx :  7 num :  [10.]
#  [DEBUG] class :  62 idx :  8 num :  [10.]
#  [DEBUG] class :  76 idx :  9 num :  [10.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [13.]
#  [DEBUG] class :  1 idx :  1 num :  [13.]
# [INFO] object height is:  0.57 [m]
#  [DEBUG] class :  1 idx :  2 num :  [13.]
# [INFO] object height is:  0.64 [m]
#  [DEBUG] class :  1 idx :  3 num :  [13.]
# [INFO] object height is:  0.46 [m]
#  [DEBUG] class :  1 idx :  4 num :  [13.]
#  [DEBUG] class :  1 idx :  5 num :  [13.]
#  [DEBUG] class :  1 idx :  6 num :  [13.]
#  [DEBUG] class :  1 idx :  7 num :  [13.]
#  [DEBUG] class :  62 idx :  8 num :  [13.]
#  [DEBUG] class :  1 idx :  9 num :  [13.]
#  [DEBUG] class :  76 idx :  10 num :  [13.]
#  [DEBUG] class :  62 idx :  11 num :  [13.]
#  [DEBUG] class :  62 idx :  12 num :  [13.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [14.]
#  [DEBUG] class :  1 idx :  1 num :  [14.]
# [INFO] object height is:  0.36 [m]
#  [DEBUG] class :  1 idx :  2 num :  [14.]
# [INFO] object height is:  0.53 [m]
#  [DEBUG] class :  1 idx :  3 num :  [14.]
# [INFO] object height is:  0.57 [m]
#  [DEBUG] class :  1 idx :  4 num :  [14.]
#  [DEBUG] class :  1 idx :  5 num :  [14.]
#  [DEBUG] class :  76 idx :  6 num :  [14.]
#  [DEBUG] class :  62 idx :  7 num :  [14.]
#  [DEBUG] class :  31 idx :  8 num :  [14.]
#  [DEBUG] class :  62 idx :  9 num :  [14.]
#  [DEBUG] class :  1 idx :  10 num :  [14.]
#  [DEBUG] class :  44 idx :  11 num :  [14.]
#  [DEBUG] class :  76 idx :  12 num :  [14.]
#  [DEBUG] class :  1 idx :  13 num :  [14.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [12.]
#  [DEBUG] class :  1 idx :  1 num :  [12.]
# [INFO] object height is:  0.6 [m]
#  [DEBUG] class :  1 idx :  2 num :  [12.]
# [INFO] object height is:  0.37 [m]
#  [DEBUG] class :  1 idx :  3 num :  [12.]
# [INFO] object height is:  0.72 [m]
#  [DEBUG] class :  1 idx :  4 num :  [12.]
# [INFO] object height is:  0.32 [m]
#  [DEBUG] class :  1 idx :  5 num :  [12.]
#  [DEBUG] class :  1 idx :  6 num :  [12.]
#  [DEBUG] class :  76 idx :  7 num :  [12.]
#  [DEBUG] class :  76 idx :  8 num :  [12.]
#  [DEBUG] class :  31 idx :  9 num :  [12.]
#  [DEBUG] class :  62 idx :  10 num :  [12.]
#  [DEBUG] class :  44 idx :  11 num :  [12.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [14.]
#  [DEBUG] class :  1 idx :  1 num :  [14.]
# [INFO] object height is:  0.6 [m]
#  [DEBUG] class :  1 idx :  2 num :  [14.]
# [INFO] object height is:  0.38 [m]
#  [DEBUG] class :  1 idx :  3 num :  [14.]
# [INFO] object height is:  0.69 [m]
#  [DEBUG] class :  1 idx :  4 num :  [14.]
#  [DEBUG] class :  76 idx :  5 num :  [14.]
#  [DEBUG] class :  62 idx :  6 num :  [14.]
#  [DEBUG] class :  76 idx :  7 num :  [14.]
#  [DEBUG] class :  31 idx :  8 num :  [14.]
#  [DEBUG] class :  1 idx :  9 num :  [14.]
#  [DEBUG] class :  62 idx :  10 num :  [14.]
#  [DEBUG] class :  64 idx :  11 num :  [14.]
#  [DEBUG] class :  49 idx :  12 num :  [14.]
#  [DEBUG] class :  1 idx :  13 num :  [14.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.58 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.39 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
# [INFO] object height is:  0.58 [m]
#  [DEBUG] class :  76 idx :  4 num :  [9.]
#  [DEBUG] class :  62 idx :  5 num :  [9.]
#  [DEBUG] class :  1 idx :  6 num :  [9.]
#  [DEBUG] class :  76 idx :  7 num :  [9.]
#  [DEBUG] class :  31 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [13.]
#  [DEBUG] class :  1 idx :  1 num :  [13.]
# [INFO] object height is:  1.24 [m]
#  [DEBUG] class :  1 idx :  2 num :  [13.]
# [INFO] object height is:  0.54 [m]
#  [DEBUG] class :  1 idx :  3 num :  [13.]
# [INFO] object height is:  0.59 [m]
#  [DEBUG] class :  76 idx :  4 num :  [13.]
#  [DEBUG] class :  76 idx :  5 num :  [13.]
#  [DEBUG] class :  1 idx :  6 num :  [13.]
#  [DEBUG] class :  1 idx :  7 num :  [13.]
#  [DEBUG] class :  1 idx :  8 num :  [13.]
#  [DEBUG] class :  62 idx :  9 num :  [13.]
#  [DEBUG] class :  32 idx :  10 num :  [13.]
#  [DEBUG] class :  62 idx :  11 num :  [13.]
#  [DEBUG] class :  62 idx :  12 num :  [13.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [14.]
#  [DEBUG] class :  1 idx :  1 num :  [14.]
# [INFO] object height is:  0.65 [m]
#  [DEBUG] class :  1 idx :  2 num :  [14.]
# [INFO] object height is:  0.44 [m]
#  [DEBUG] class :  1 idx :  3 num :  [14.]
# [INFO] object height is:  0.57 [m]
#  [DEBUG] class :  62 idx :  4 num :  [14.]
#  [DEBUG] class :  76 idx :  5 num :  [14.]
#  [DEBUG] class :  62 idx :  6 num :  [14.]
#  [DEBUG] class :  62 idx :  7 num :  [14.]
#  [DEBUG] class :  44 idx :  8 num :  [14.]
#  [DEBUG] class :  76 idx :  9 num :  [14.]
#  [DEBUG] class :  1 idx :  10 num :  [14.]
#  [DEBUG] class :  62 idx :  11 num :  [14.]
#  [DEBUG] class :  1 idx :  12 num :  [14.]
#  [DEBUG] class :  1 idx :  13 num :  [14.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [14.]
#  [DEBUG] class :  1 idx :  1 num :  [14.]
# [INFO] object height is:  0.49 [m]
#  [DEBUG] class :  1 idx :  2 num :  [14.]
# [INFO] object height is:  0.89 [m]
#  [DEBUG] class :  1 idx :  3 num :  [14.]
# [INFO] object height is:  0.57 [m]
#  [DEBUG] class :  1 idx :  4 num :  [14.]
#  [DEBUG] class :  76 idx :  5 num :  [14.]
#  [DEBUG] class :  1 idx :  6 num :  [14.]
#  [DEBUG] class :  1 idx :  7 num :  [14.]
#  [DEBUG] class :  62 idx :  8 num :  [14.]
#  [DEBUG] class :  62 idx :  9 num :  [14.]
#  [DEBUG] class :  76 idx :  10 num :  [14.]
#  [DEBUG] class :  62 idx :  11 num :  [14.]
#  [DEBUG] class :  1 idx :  12 num :  [14.]
#  [DEBUG] class :  32 idx :  13 num :  [14.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [13.]
#  [DEBUG] class :  1 idx :  1 num :  [13.]
# [INFO] object height is:  0.99 [m]
#  [DEBUG] class :  1 idx :  2 num :  [13.]
# [INFO] object height is:  0.41 [m]
#  [DEBUG] class :  1 idx :  3 num :  [13.]
# [INFO] object height is:  0.67 [m]
#  [DEBUG] class :  1 idx :  4 num :  [13.]
#  [DEBUG] class :  76 idx :  5 num :  [13.]
#  [DEBUG] class :  1 idx :  6 num :  [13.]
#  [DEBUG] class :  76 idx :  7 num :  [13.]
#  [DEBUG] class :  1 idx :  8 num :  [13.]
#  [DEBUG] class :  62 idx :  9 num :  [13.]
#  [DEBUG] class :  62 idx :  10 num :  [13.]
#  [DEBUG] class :  32 idx :  11 num :  [13.]
#  [DEBUG] class :  62 idx :  12 num :  [13.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [17.]
#  [DEBUG] class :  1 idx :  1 num :  [17.]
# [INFO] object height is:  1.05 [m]
#  [DEBUG] class :  1 idx :  2 num :  [17.]
# [INFO] object height is:  0.48 [m]
#  [DEBUG] class :  76 idx :  3 num :  [17.]
#  [DEBUG] class :  1 idx :  4 num :  [17.]
#  [DEBUG] class :  1 idx :  5 num :  [17.]
#  [DEBUG] class :  62 idx :  6 num :  [17.]
#  [DEBUG] class :  76 idx :  7 num :  [17.]
#  [DEBUG] class :  1 idx :  8 num :  [17.]
#  [DEBUG] class :  1 idx :  9 num :  [17.]
#  [DEBUG] class :  31 idx :  10 num :  [17.]
#  [DEBUG] class :  32 idx :  11 num :  [17.]
#  [DEBUG] class :  73 idx :  12 num :  [17.]
#  [DEBUG] class :  62 idx :  13 num :  [17.]
#  [DEBUG] class :  62 idx :  14 num :  [17.]
#  [DEBUG] class :  62 idx :  15 num :  [17.]
#  [DEBUG] class :  1 idx :  16 num :  [17.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [15.]
#  [DEBUG] class :  1 idx :  1 num :  [15.]
# [INFO] object height is:  0.96 [m]
#  [DEBUG] class :  1 idx :  2 num :  [15.]
# [INFO] object height is:  1.22 [m]
#  [DEBUG] class :  1 idx :  3 num :  [15.]
# [INFO] object height is:  0.82 [m]
#  [DEBUG] class :  76 idx :  4 num :  [15.]
#  [DEBUG] class :  76 idx :  5 num :  [15.]
#  [DEBUG] class :  62 idx :  6 num :  [15.]
#  [DEBUG] class :  1 idx :  7 num :  [15.]
#  [DEBUG] class :  62 idx :  8 num :  [15.]
#  [DEBUG] class :  62 idx :  9 num :  [15.]
#  [DEBUG] class :  62 idx :  10 num :  [15.]
#  [DEBUG] class :  1 idx :  11 num :  [15.]
#  [DEBUG] class :  31 idx :  12 num :  [15.]
#  [DEBUG] class :  1 idx :  13 num :  [15.]
#  [DEBUG] class :  72 idx :  14 num :  [15.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [15.]
#  [DEBUG] class :  1 idx :  1 num :  [15.]
# [INFO] object height is:  0.83 [m]
#  [DEBUG] class :  1 idx :  2 num :  [15.]
# [INFO] object height is:  1.07 [m]
#  [DEBUG] class :  1 idx :  3 num :  [15.]
# [INFO] object height is:  0.43 [m]
#  [DEBUG] class :  76 idx :  4 num :  [15.]
#  [DEBUG] class :  1 idx :  5 num :  [15.]
#  [DEBUG] class :  76 idx :  6 num :  [15.]
#  [DEBUG] class :  62 idx :  7 num :  [15.]
#  [DEBUG] class :  1 idx :  8 num :  [15.]
#  [DEBUG] class :  1 idx :  9 num :  [15.]
#  [DEBUG] class :  62 idx :  10 num :  [15.]
#  [DEBUG] class :  1 idx :  11 num :  [15.]
#  [DEBUG] class :  1 idx :  12 num :  [15.]
#  [DEBUG] class :  31 idx :  13 num :  [15.]
#  [DEBUG] class :  62 idx :  14 num :  [15.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [13.]
#  [DEBUG] class :  1 idx :  1 num :  [13.]
# [INFO] object height is:  1.08 [m]
#  [DEBUG] class :  1 idx :  2 num :  [13.]
# [INFO] object height is:  1.12 [m]
#  [DEBUG] class :  1 idx :  3 num :  [13.]
# [INFO] object height is:  0.83 [m]
#  [DEBUG] class :  76 idx :  4 num :  [13.]
#  [DEBUG] class :  1 idx :  5 num :  [13.]
#  [DEBUG] class :  76 idx :  6 num :  [13.]
#  [DEBUG] class :  62 idx :  7 num :  [13.]
#  [DEBUG] class :  62 idx :  8 num :  [13.]
#  [DEBUG] class :  31 idx :  9 num :  [13.]
#  [DEBUG] class :  1 idx :  10 num :  [13.]
#  [DEBUG] class :  32 idx :  11 num :  [13.]
#  [DEBUG] class :  1 idx :  12 num :  [13.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [10.]
#  [DEBUG] class :  1 idx :  1 num :  [10.]
# [INFO] object height is:  1.05 [m]
#  [DEBUG] class :  1 idx :  2 num :  [10.]
# [INFO] object height is:  0.84 [m]
#  [DEBUG] class :  1 idx :  3 num :  [10.]
# [INFO] object height is:  0.49 [m]
#  [DEBUG] class :  76 idx :  4 num :  [10.]
#  [DEBUG] class :  76 idx :  5 num :  [10.]
#  [DEBUG] class :  62 idx :  6 num :  [10.]
#  [DEBUG] class :  62 idx :  7 num :  [10.]
#  [DEBUG] class :  32 idx :  8 num :  [10.]
#  [DEBUG] class :  31 idx :  9 num :  [10.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [11.]
#  [DEBUG] class :  1 idx :  1 num :  [11.]
# [INFO] object height is:  1.0 [m]
#  [DEBUG] class :  1 idx :  2 num :  [11.]
# [INFO] object height is:  0.83 [m]
#  [DEBUG] class :  1 idx :  3 num :  [11.]
# [INFO] object height is:  0.46 [m]
#  [DEBUG] class :  76 idx :  4 num :  [11.]
#  [DEBUG] class :  1 idx :  5 num :  [11.]
#  [DEBUG] class :  62 idx :  6 num :  [11.]
#  [DEBUG] class :  62 idx :  7 num :  [11.]
#  [DEBUG] class :  76 idx :  8 num :  [11.]
#  [DEBUG] class :  32 idx :  9 num :  [11.]
#  [DEBUG] class :  62 idx :  10 num :  [11.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [14.]
#  [DEBUG] class :  1 idx :  1 num :  [14.]
# [INFO] object height is:  0.98 [m]
#  [DEBUG] class :  1 idx :  2 num :  [14.]
# [INFO] object height is:  0.85 [m]
#  [DEBUG] class :  1 idx :  3 num :  [14.]
# [INFO] object height is:  0.49 [m]
#  [DEBUG] class :  76 idx :  4 num :  [14.]
#  [DEBUG] class :  62 idx :  5 num :  [14.]
#  [DEBUG] class :  62 idx :  6 num :  [14.]
#  [DEBUG] class :  62 idx :  7 num :  [14.]
#  [DEBUG] class :  62 idx :  8 num :  [14.]
#  [DEBUG] class :  32 idx :  9 num :  [14.]
#  [DEBUG] class :  1 idx :  10 num :  [14.]
#  [DEBUG] class :  1 idx :  11 num :  [14.]
#  [DEBUG] class :  62 idx :  12 num :  [14.]
#  [DEBUG] class :  62 idx :  13 num :  [14.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [14.]
#  [DEBUG] class :  1 idx :  1 num :  [14.]
# [INFO] object height is:  1.0 [m]
#  [DEBUG] class :  1 idx :  2 num :  [14.]
# [INFO] object height is:  0.91 [m]
#  [DEBUG] class :  76 idx :  3 num :  [14.]
#  [DEBUG] class :  1 idx :  4 num :  [14.]
#  [DEBUG] class :  76 idx :  5 num :  [14.]
#  [DEBUG] class :  1 idx :  6 num :  [14.]
#  [DEBUG] class :  62 idx :  7 num :  [14.]
#  [DEBUG] class :  1 idx :  8 num :  [14.]
#  [DEBUG] class :  62 idx :  9 num :  [14.]
#  [DEBUG] class :  62 idx :  10 num :  [14.]
#  [DEBUG] class :  32 idx :  11 num :  [14.]
#  [DEBUG] class :  62 idx :  12 num :  [14.]
#  [DEBUG] class :  1 idx :  13 num :  [14.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [15.]
#  [DEBUG] class :  1 idx :  1 num :  [15.]
# [INFO] object height is:  1.08 [m]
#  [DEBUG] class :  1 idx :  2 num :  [15.]
# [INFO] object height is:  0.71 [m]
#  [DEBUG] class :  76 idx :  3 num :  [15.]
#  [DEBUG] class :  1 idx :  4 num :  [15.]
#  [DEBUG] class :  62 idx :  5 num :  [15.]
#  [DEBUG] class :  76 idx :  6 num :  [15.]
#  [DEBUG] class :  1 idx :  7 num :  [15.]
#  [DEBUG] class :  62 idx :  8 num :  [15.]
#  [DEBUG] class :  62 idx :  9 num :  [15.]
#  [DEBUG] class :  62 idx :  10 num :  [15.]
#  [DEBUG] class :  62 idx :  11 num :  [15.]
#  [DEBUG] class :  1 idx :  12 num :  [15.]
#  [DEBUG] class :  31 idx :  13 num :  [15.]
#  [DEBUG] class :  19 idx :  14 num :  [15.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [15.]
#  [DEBUG] class :  1 idx :  1 num :  [15.]
# [INFO] object height is:  0.9 [m]
#  [DEBUG] class :  76 idx :  2 num :  [15.]
#  [DEBUG] class :  1 idx :  3 num :  [15.]
# [INFO] object height is:  0.7 [m]
#  [DEBUG] class :  1 idx :  4 num :  [15.]
# [INFO] object height is:  0.77 [m]
#  [DEBUG] class :  1 idx :  5 num :  [15.]
# [INFO] object height is:  0.49 [m]
#  [DEBUG] class :  1 idx :  6 num :  [15.]
#  [DEBUG] class :  62 idx :  7 num :  [15.]
#  [DEBUG] class :  62 idx :  8 num :  [15.]
#  [DEBUG] class :  76 idx :  9 num :  [15.]
#  [DEBUG] class :  62 idx :  10 num :  [15.]
#  [DEBUG] class :  62 idx :  11 num :  [15.]
#  [DEBUG] class :  1 idx :  12 num :  [15.]
#  [DEBUG] class :  62 idx :  13 num :  [15.]
#  [DEBUG] class :  62 idx :  14 num :  [15.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [16.]
#  [DEBUG] class :  1 idx :  1 num :  [16.]
# [INFO] object height is:  1.01 [m]
#  [DEBUG] class :  1 idx :  2 num :  [16.]
# [INFO] object height is:  0.73 [m]
#  [DEBUG] class :  62 idx :  3 num :  [16.]
#  [DEBUG] class :  76 idx :  4 num :  [16.]
#  [DEBUG] class :  1 idx :  5 num :  [16.]
# [INFO] object height is:  0.85 [m]
#  [DEBUG] class :  1 idx :  6 num :  [16.]
#  [DEBUG] class :  62 idx :  7 num :  [16.]
#  [DEBUG] class :  1 idx :  8 num :  [16.]
#  [DEBUG] class :  62 idx :  9 num :  [16.]
#  [DEBUG] class :  76 idx :  10 num :  [16.]
#  [DEBUG] class :  62 idx :  11 num :  [16.]
#  [DEBUG] class :  62 idx :  12 num :  [16.]
#  [DEBUG] class :  1 idx :  13 num :  [16.]
#  [DEBUG] class :  62 idx :  14 num :  [16.]
#  [DEBUG] class :  32 idx :  15 num :  [16.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [18.]
#  [DEBUG] class :  1 idx :  1 num :  [18.]
# [INFO] object height is:  1.06 [m]
#  [DEBUG] class :  1 idx :  2 num :  [18.]
# [INFO] object height is:  1.15 [m]
#  [DEBUG] class :  62 idx :  3 num :  [18.]
#  [DEBUG] class :  1 idx :  4 num :  [18.]
# [INFO] object height is:  0.51 [m]
#  [DEBUG] class :  76 idx :  5 num :  [18.]
#  [DEBUG] class :  1 idx :  6 num :  [18.]
#  [DEBUG] class :  1 idx :  7 num :  [18.]
#  [DEBUG] class :  62 idx :  8 num :  [18.]
#  [DEBUG] class :  76 idx :  9 num :  [18.]
#  [DEBUG] class :  62 idx :  10 num :  [18.]
#  [DEBUG] class :  62 idx :  11 num :  [18.]
#  [DEBUG] class :  62 idx :  12 num :  [18.]
#  [DEBUG] class :  1 idx :  13 num :  [18.]
#  [DEBUG] class :  62 idx :  14 num :  [18.]
#  [DEBUG] class :  62 idx :  15 num :  [18.]
#  [DEBUG] class :  62 idx :  16 num :  [18.]
#  [DEBUG] class :  19 idx :  17 num :  [18.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [10.]
#  [DEBUG] class :  1 idx :  1 num :  [10.]
# [INFO] object height is:  0.99 [m]
# ...
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.6 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.34 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
#  [DEBUG] class :  62 idx :  4 num :  [9.]
#  [DEBUG] class :  1 idx :  5 num :  [9.]
#  [DEBUG] class :  62 idx :  6 num :  [9.]
#  [DEBUG] class :  76 idx :  7 num :  [9.]
#  [DEBUG] class :  62 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.61 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.34 [m]
#  [DEBUG] class :  70 idx :  3 num :  [9.]
#  [DEBUG] class :  1 idx :  4 num :  [9.]
#  [DEBUG] class :  62 idx :  5 num :  [9.]
#  [DEBUG] class :  76 idx :  6 num :  [9.]
#  [DEBUG] class :  1 idx :  7 num :  [9.]
#  [DEBUG] class :  62 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [10.]
#  [DEBUG] class :  1 idx :  1 num :  [10.]
# [INFO] object height is:  0.61 [m]
#  [DEBUG] class :  1 idx :  2 num :  [10.]
# [INFO] object height is:  0.34 [m]
#  [DEBUG] class :  1 idx :  3 num :  [10.]
#  [DEBUG] class :  1 idx :  4 num :  [10.]
#  [DEBUG] class :  70 idx :  5 num :  [10.]
#  [DEBUG] class :  76 idx :  6 num :  [10.]
#  [DEBUG] class :  62 idx :  7 num :  [10.]
#  [DEBUG] class :  70 idx :  8 num :  [10.]
#  [DEBUG] class :  62 idx :  9 num :  [10.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [11.]
#  [DEBUG] class :  1 idx :  1 num :  [11.]
# [INFO] object height is:  0.62 [m]
#  [DEBUG] class :  1 idx :  2 num :  [11.]
# [INFO] object height is:  0.34 [m]
#  [DEBUG] class :  1 idx :  3 num :  [11.]
#  [DEBUG] class :  76 idx :  4 num :  [11.]
#  [DEBUG] class :  1 idx :  5 num :  [11.]
#  [DEBUG] class :  70 idx :  6 num :  [11.]
#  [DEBUG] class :  62 idx :  7 num :  [11.]
#  [DEBUG] class :  62 idx :  8 num :  [11.]
#  [DEBUG] class :  62 idx :  9 num :  [11.]
#  [DEBUG] class :  62 idx :  10 num :  [11.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [10.]
#  [DEBUG] class :  1 idx :  1 num :  [10.]
# [INFO] object height is:  0.66 [m]
#  [DEBUG] class :  1 idx :  2 num :  [10.]
# [INFO] object height is:  0.34 [m]
#  [DEBUG] class :  1 idx :  3 num :  [10.]
#  [DEBUG] class :  1 idx :  4 num :  [10.]
#  [DEBUG] class :  70 idx :  5 num :  [10.]
#  [DEBUG] class :  70 idx :  6 num :  [10.]
#  [DEBUG] class :  62 idx :  7 num :  [10.]
#  [DEBUG] class :  1 idx :  8 num :  [10.]
#  [DEBUG] class :  76 idx :  9 num :  [10.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [8.]
#  [DEBUG] class :  1 idx :  1 num :  [8.]
# [INFO] object height is:  0.64 [m]
#  [DEBUG] class :  1 idx :  2 num :  [8.]
# [INFO] object height is:  0.34 [m]
#  [DEBUG] class :  70 idx :  3 num :  [8.]
#  [DEBUG] class :  62 idx :  4 num :  [8.]
#  [DEBUG] class :  1 idx :  5 num :  [8.]
#  [DEBUG] class :  76 idx :  6 num :  [8.]
#  [DEBUG] class :  62 idx :  7 num :  [8.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.62 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.37 [m]
#  [DEBUG] class :  62 idx :  3 num :  [9.]
#  [DEBUG] class :  1 idx :  4 num :  [9.]
#  [DEBUG] class :  62 idx :  5 num :  [9.]
#  [DEBUG] class :  76 idx :  6 num :  [9.]
#  [DEBUG] class :  62 idx :  7 num :  [9.]
#  [DEBUG] class :  70 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.41 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.56 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
#  [DEBUG] class :  1 idx :  4 num :  [9.]
#  [DEBUG] class :  1 idx :  5 num :  [9.]
#  [DEBUG] class :  1 idx :  6 num :  [9.]
#  [DEBUG] class :  76 idx :  7 num :  [9.]
#  [DEBUG] class :  62 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  1 idx :  0 num :  [9.]
# [INFO] object height is:  0.42 [m]
#  [DEBUG] class :  73 idx :  1 num :  [9.]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.56 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
# [INFO] object height is:  0.37 [m]
#  [DEBUG] class :  76 idx :  4 num :  [9.]
#  [DEBUG] class :  1 idx :  5 num :  [9.]
#  [DEBUG] class :  1 idx :  6 num :  [9.]
#  [DEBUG] class :  76 idx :  7 num :  [9.]
#  [DEBUG] class :  1 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  1 idx :  0 num :  [13.]
# [INFO] object height is:  0.32 [m]
#  [DEBUG] class :  1 idx :  1 num :  [13.]
# [INFO] object height is:  0.55 [m]
#  [DEBUG] class :  73 idx :  2 num :  [13.]
#  [DEBUG] class :  1 idx :  3 num :  [13.]
#  [DEBUG] class :  1 idx :  4 num :  [13.]
#  [DEBUG] class :  19 idx :  5 num :  [13.]
#  [DEBUG] class :  1 idx :  6 num :  [13.]
#  [DEBUG] class :  1 idx :  7 num :  [13.]
#  [DEBUG] class :  73 idx :  8 num :  [13.]
#  [DEBUG] class :  1 idx :  9 num :  [13.]
#  [DEBUG] class :  62 idx :  10 num :  [13.]
#  [DEBUG] class :  62 idx :  11 num :  [13.]
#  [DEBUG] class :  15 idx :  12 num :  [13.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  1 idx :  0 num :  [11.]
# [INFO] object height is:  0.55 [m]
#  [DEBUG] class :  1 idx :  1 num :  [11.]
# [INFO] object height is:  0.31 [m]
#  [DEBUG] class :  1 idx :  2 num :  [11.]
# [INFO] object height is:  0.27 [m]
#  [DEBUG] class :  1 idx :  3 num :  [11.]
# [INFO] object height is:  0.66 [m]
#  [DEBUG] class :  73 idx :  4 num :  [11.]
#  [DEBUG] class :  1 idx :  5 num :  [11.]
# [INFO] object height is:  0.26 [m]
#  [DEBUG] class :  1 idx :  6 num :  [11.]
#  [DEBUG] class :  62 idx :  7 num :  [11.]
#  [DEBUG] class :  19 idx :  8 num :  [11.]
#  [DEBUG] class :  73 idx :  9 num :  [11.]
#  [DEBUG] class :  62 idx :  10 num :  [11.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  1 idx :  0 num :  [12.]
# [INFO] object height is:  0.31 [m]
#  [DEBUG] class :  1 idx :  1 num :  [12.]
# [INFO] object height is:  0.47 [m]
#  [DEBUG] class :  73 idx :  2 num :  [12.]
#  [DEBUG] class :  1 idx :  3 num :  [12.]
# [INFO] object height is:  0.31 [m]
#  [DEBUG] class :  1 idx :  4 num :  [12.]
# [INFO] object height is:  0.31 [m]
#  [DEBUG] class :  1 idx :  5 num :  [12.]
#  [DEBUG] class :  1 idx :  6 num :  [12.]
#  [DEBUG] class :  1 idx :  7 num :  [12.]
#  [DEBUG] class :  62 idx :  8 num :  [12.]
#  [DEBUG] class :  62 idx :  9 num :  [12.]
#  [DEBUG] class :  76 idx :  10 num :  [12.]
#  [DEBUG] class :  62 idx :  11 num :  [12.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  1 idx :  0 num :  [8.]
# [INFO] object height is:  0.47 [m]
#  [DEBUG] class :  1 idx :  1 num :  [8.]
# [INFO] object height is:  0.3 [m]
#  [DEBUG] class :  1 idx :  2 num :  [8.]
# [INFO] object height is:  0.3 [m]
#  [DEBUG] class :  73 idx :  3 num :  [8.]
#  [DEBUG] class :  1 idx :  4 num :  [8.]
#  [DEBUG] class :  1 idx :  5 num :  [8.]
#  [DEBUG] class :  1 idx :  6 num :  [8.]
#  [DEBUG] class :  19 idx :  7 num :  [8.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  1 idx :  0 num :  [11.]
# [INFO] object height is:  0.48 [m]
#  [DEBUG] class :  73 idx :  1 num :  [11.]
#  [DEBUG] class :  1 idx :  2 num :  [11.]
# [INFO] object height is:  0.25 [m]
#  [DEBUG] class :  1 idx :  3 num :  [11.]
# [INFO] object height is:  0.3 [m]
#  [DEBUG] class :  47 idx :  4 num :  [11.]
#  [DEBUG] class :  1 idx :  5 num :  [11.]
#  [DEBUG] class :  1 idx :  6 num :  [11.]
#  [DEBUG] class :  76 idx :  7 num :  [11.]
#  [DEBUG] class :  1 idx :  8 num :  [11.]
#  [DEBUG] class :  1 idx :  9 num :  [11.]
#  [DEBUG] class :  62 idx :  10 num :  [11.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  1 idx :  0 num :  [12.]
# [INFO] object height is:  0.46 [m]
#  [DEBUG] class :  1 idx :  1 num :  [12.]
# [INFO] object height is:  0.25 [m]
#  [DEBUG] class :  73 idx :  2 num :  [12.]
#  [DEBUG] class :  1 idx :  3 num :  [12.]
# [INFO] object height is:  0.29 [m]
#  [DEBUG] class :  1 idx :  4 num :  [12.]
#  [DEBUG] class :  1 idx :  5 num :  [12.]
#  [DEBUG] class :  1 idx :  6 num :  [12.]
#  [DEBUG] class :  1 idx :  7 num :  [12.]
#  [DEBUG] class :  19 idx :  8 num :  [12.]
#  [DEBUG] class :  67 idx :  9 num :  [12.]
#  [DEBUG] class :  76 idx :  10 num :  [12.]
#  [DEBUG] class :  62 idx :  11 num :  [12.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  1 idx :  0 num :  [9.]
# [INFO] object height is:  0.46 [m]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.28 [m]
#  [DEBUG] class :  73 idx :  2 num :  [9.]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
# [INFO] object height is:  0.3 [m]
#  [DEBUG] class :  1 idx :  4 num :  [9.]
#  [DEBUG] class :  1 idx :  5 num :  [9.]
#  [DEBUG] class :  1 idx :  6 num :  [9.]
#  [DEBUG] class :  1 idx :  7 num :  [9.]
#  [DEBUG] class :  62 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  1 idx :  0 num :  [7.]
# [INFO] object height is:  0.46 [m]
#  [DEBUG] class :  1 idx :  1 num :  [7.]
# [INFO] object height is:  0.25 [m]
#  [DEBUG] class :  73 idx :  2 num :  [7.]
#  [DEBUG] class :  1 idx :  3 num :  [7.]
# [INFO] object height is:  0.29 [m]
#  [DEBUG] class :  1 idx :  4 num :  [7.]
#  [DEBUG] class :  1 idx :  5 num :  [7.]
#  [DEBUG] class :  1 idx :  6 num :  [7.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  73 idx :  0 num :  [9.]
#  [DEBUG] class :  1 idx :  1 num :  [9.]
# [INFO] object height is:  0.49 [m]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.25 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
# [INFO] object height is:  0.27 [m]
#  [DEBUG] class :  1 idx :  4 num :  [9.]
#  [DEBUG] class :  1 idx :  5 num :  [9.]
#  [DEBUG] class :  1 idx :  6 num :  [9.]
#  [DEBUG] class :  76 idx :  7 num :  [9.]
#  [DEBUG] class :  62 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  1 idx :  0 num :  [10.]
# [INFO] object height is:  0.48 [m]
#  [DEBUG] class :  73 idx :  1 num :  [10.]
#  [DEBUG] class :  1 idx :  2 num :  [10.]
# [INFO] object height is:  0.28 [m]
#  [DEBUG] class :  1 idx :  3 num :  [10.]
# [INFO] object height is:  0.3 [m]
#  [DEBUG] class :  1 idx :  4 num :  [10.]
#  [DEBUG] class :  1 idx :  5 num :  [10.]
#  [DEBUG] class :  76 idx :  6 num :  [10.]
#  [DEBUG] class :  1 idx :  7 num :  [10.]
#  [DEBUG] class :  1 idx :  8 num :  [10.]
#  [DEBUG] class :  1 idx :  9 num :  [10.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  1 idx :  0 num :  [9.]
# [INFO] object height is:  0.47 [m]
#  [DEBUG] class :  73 idx :  1 num :  [9.]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.25 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
# [INFO] object height is:  0.3 [m]
#  [DEBUG] class :  76 idx :  4 num :  [9.]
#  [DEBUG] class :  1 idx :  5 num :  [9.]
#  [DEBUG] class :  1 idx :  6 num :  [9.]
#  [DEBUG] class :  1 idx :  7 num :  [9.]
#  [DEBUG] class :  19 idx :  8 num :  [9.]
# [INFO] drawing bounding box on detected objects...
# [INFO] each detected object has a unique color
#  [DEBUG] class :  1 idx :  0 num :  [9.]
# [INFO] object height is:  0.5 [m]
#  [DEBUG] class :  73 idx :  1 num :  [9.]
#  [DEBUG] class :  1 idx :  2 num :  [9.]
# [INFO] object height is:  0.25 [m]
#  [DEBUG] class :  1 idx :  3 num :  [9.]
# [INFO] object height is:  0.28 [m]
#  [DEBUG] class :  1 idx :  4 num :  [9.]
#  [DEBUG] class :  1 idx :  5 num :  [9.]
#  [DEBUG] class :  73 idx :  6 num :  [9.]
#  [DEBUG] class :  1 idx :  7 num :  [9.]
#  [DEBUG] class :  76 idx :  8 num :  [9.]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 64
#      62 image_expanded = np.expand_dims(color_image, axis=0)
#      63 # Perform the actual detection by running the model with the image as input
# ---> 64 (boxes, scores, classes, num) = sess.run([detection_boxes, detection_scores, detection_classes, num_detections],
#      65                                          feed_dict={image_tensor: image_expanded})
#      67 boxes = np.squeeze(boxes)
#      68 classes = np.squeeze(classes).astype(np.int32)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/client/session.py:972, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     969 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     971 try:
# --> 972   result = self._run(None, fetches, feed_dict, options_ptr,
#     973                      run_metadata_ptr)
#     974   if run_metadata:
#     975     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/client/session.py:1215, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1212 # We only want to really perform the run if fetches or targets are provided,
#    1213 # or if the call is a partial run that specifies feeds.
#    1214 if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1215   results = self._do_run(handle, final_targets, final_fetches,
#    1216                          feed_dict_tensor, options, run_metadata)
#    1217 else:
#    1218   results = []
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/client/session.py:1395, in BaseSession._do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1392   return self._call_tf_sessionprun(handle, feed_dict, fetch_list)
#    1394 if handle is None:
# -> 1395   return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1396                        run_metadata)
#    1397 else:
#    1398   return self._do_call(_prun_fn, handle, feeds, fetches)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/client/session.py:1402, in BaseSession._do_call(self, fn, *args)
#    1400 def _do_call(self, fn, *args):
#    1401   try:
# -> 1402     return fn(*args)
#    1403   except errors.OpError as e:
#    1404     message = compat.as_text(e.message)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/client/session.py:1385, in BaseSession._do_run.<locals>._run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1382 def _run_fn(feed_dict, fetch_list, target_list, options, run_metadata):
#    1383   # Ensure any changes to the graph are reflected in the runtime.
#    1384   self._extend_graph()
# -> 1385   return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1386                                   target_list, run_metadata)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/client/session.py:1478, in BaseSession._call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1476 def _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list,
#    1477                         run_metadata):
# -> 1478   return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1479                                           fetch_list, target_list,
#    1480                                           run_metadata)
#
# KeyboardInterrupt:
